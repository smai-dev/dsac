# %%
numberOfStudents = 20
averageGrade = 67.46

class(numberOfStudents)
class(averageGrade)

numberOfStudents
averageGrade
# Out:
# [1] "numeric"
# [1] "numeric"
# [1] 20
# [1] 67.46

# %%
numberOfStudents = 20L 
MSCstudent = TRUE

class(numberOfStudents)
class(MSCstudent)
# Out:
# [1] "integer"
# [1] "logical"

# %%
studentGrades = c(74.5, 85.3, 92.7)
studentGrades
studentGrades[2]
studentGrades = c(studentGrades,"100.3")
# Out:
# [1] 74.5 85.3 92.7
# [1] 85.3

# %%
lastName = c("Hofmann","Nolan", "Gray")
lastName = c(lastName, "Tracey")
lastName

lastName[2] #shows individual value   2nd place value
lastName[3] #shows individual value   3rd place value
# Out:
# [1] "Hofmann" "Nolan"   "Gray"    "Tracey"
# [1] "Nolan"
# [1] "Gray"

# %%
resultList = list(names = lastName, grades = studentGrades)
resultList

resultList$names  #Lists only one vector within the list
resultList$names[2] # Lists second entry of the names vector
# Out:
# $names
# [1] "Hofmann" "Nolan"   "Gray"    "Tracey"
#
# $grades
# [1] "74.5"  "85.3"  "92.7"  "100.3"
# [1] "Hofmann" "Nolan"   "Gray"    "Tracey"
# [1] "Nolan"

# %%
newMatrix = matrix(c(1,2,3,4,5,6,9, 11,10), byrow = F, ncol = 3)
newMatrix
# Out:
#      [,1] [,2] [,3]
# [1,] 1    4     9
# [2,] 2    5    11
# [3,] 3    6    10

# %%
studentResultsDataFrame = data.frame(names = lastName, grades = studentGrades)
studentResultsDataFrame
# Out:
#   names   grades
# 1 Hofmann 74.5
# 2 Nolan   85.3
# 3 Gray    92.7
# 4 Tracey  100.3

# %%
mean(studentResultsDataFrame$grades)
# Out:
# Warning message in mean.default(studentResultsDataFrame$grades):
# “argument is not numeric or logical: returning NA”
# [1] NA

# %%
studentGrades = c(74.5, 85.3, 92.7, NA)
studentGrades

is.na(studentGrades)
# Out:
# [1] 74.5 85.3 92.7   NA
# [1] FALSE FALSE FALSE  TRUE

# %%
mean    #this shows some general info
methods(mean) # shows the methods
?mean
getAnywhere(mean.default)
x <- c(0:10, 50)
x
xm <- mean(x)
c(xm, mean(x, trim = 0.10))
# Out:
# function (x, ...)
# UseMethod("mean")
# <bytecode: 0x5574a200b968>
# <environment: namespace:base>
# [1] mean.Date        mean.default     mean.difftime    mean.POSIXct
# [5] mean.POSIXlt     mean.quosure*    mean.vctrs_vctr*
# see '?methods' for accessing help and source code
# A single object matching ‘mean.default’ was found
# It was found in the following places
#   package:base
#   registered S3 method for mean from namespace base
#   namespace:base
# with value
#
# function (x, trim = 0, na.rm = FALSE, ...)
# {
#     if (!is.numeric(x) && !is.complex(x) && !is.logical(x)) {
#         warning("argument is not numeric or logical: returning NA")
#         return(NA_real_)
#     }
#     if (isTRUE(na.rm))
#         x <- x[!is.na(x)]
#     if (!is.numeric(trim) || length(trim) != 1L)
#         stop("'trim' must be numeric of length one")
#     n <- length(x)
#     if (trim > 0 && n) {
#         if (is.complex(x))
#             stop("trimmed means are not defined for complex data")
# ...
